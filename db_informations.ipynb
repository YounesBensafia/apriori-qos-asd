# %%
import pandas as pd
import os
from collections import Counter
import matplotlib.pyplot as plt

def load_transactions():
    """
    Load transactions from the CSV file
    """
    current_dir = os.getcwd()
    filepath = os.path.join(current_dir, 'database', 'Autism_Data.csv')
    
    try:
        df = pd.read_csv(filepath)
        return df
    except FileNotFoundError:
        print(f"Error: database.csv not found in {current_dir}")
        return None

# %%
print("Loading database...")
df = load_transactions()
# Get columns that don't contain just 0s and 1s
non_binary_cols = []
for col in df.columns:
    unique_vals = df[col].unique()
    if not all(val in [0, 1] for val in unique_vals if pd.notna(val)):
        non_binary_cols.append(col)

print("Columns that are not binary (0/1):")
print(non_binary_cols)
# Out:
# Loading database...
# Columns that are not binary (0/1):
# ['age', 'gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before', 'result', 'age_desc', 'relation', 'Class']

# %%
# Count frequency of each age value
unique_ages = df["age"].unique()
unique_ages.sort()

print("Unique ages:")
for age in unique_ages:
    print(f"Age {age}")
# Out:
# Unique ages:
# Age 17
# Age 18
# Age 19
# Age 20
# Age 21
# Age 22
# Age 23
# Age 24
# Age 25
# Age 26
# Age 27
# Age 28
# Age 29
# Age 30
# Age 31
# Age 32
# Age 33
# Age 34
# Age 35
# Age 36
# Age 37
# Age 38
# Age 383
# Age 39
# Age 40
# Age 41
# Age 42
# Age 43
# Age 44
# Age 45
# Age 46
# Age 47
# Age 48
# Age 49
# Age 50
# Age 51
# Age 52
# Age 53
# Age 54
# Age 55
# Age 56
# Age 58
# Age 59
# Age 60
# Age 61
# Age 64
# Age ?

# %%
# Drop rows where age is '?' or 383
df = df[~df['age'].isin(['?', '383'])]
# Count frequency of each age value
unique_ages = df["age"].unique()
unique_ages.sort()

print("Unique ages:")
for age in unique_ages:
    print(f"Age {age}")
# Out:
# Unique ages:
# Age 17
# Age 18
# Age 19
# Age 20
# Age 21
# Age 22
# Age 23
# Age 24
# Age 25
# Age 26
# Age 27
# Age 28
# Age 29
# Age 30
# Age 31
# Age 32
# Age 33
# Age 34
# Age 35
# Age 36
# Age 37
# Age 38
# Age 39
# Age 40
# Age 41
# Age 42
# Age 43
# Age 44
# Age 45
# Age 46
# Age 47
# Age 48
# Age 49
# Age 50
# Age 51
# Age 52
# Age 53
# Age 54
# Age 55
# Age 56
# Age 58
# Age 59
# Age 60
# Age 61
# Age 64

# %%
# Convert age column to numeric type
df['age'] = pd.to_numeric(df['age'])

# Count frequency of each age value
unique_ages = df["age"].unique()
unique_ages.sort()

print("Unique ages:")
for age in unique_ages:
    print(f"Age {age}")
# Out:
# Unique ages:
# Age 17
# Age 18
# Age 19
# Age 20
# Age 21
# Age 22
# Age 23
# Age 24
# Age 25
# Age 26
# Age 27
# Age 28
# Age 29
# Age 30
# Age 31
# Age 32
# Age 33
# Age 34
# Age 35
# Age 36
# Age 37
# Age 38
# Age 39
# Age 40
# Age 41
# Age 42
# Age 43
# Age 44
# Age 45
# Age 46
# Age 47
# Age 48
# Age 49
# Age 50
# Age 51
# Age 52
# Age 53
# Age 54
# Age 55
# Age 56
# Age 58
# Age 59
# Age 60
# Age 61
# Age 64

# %%
df['gender'] = df['gender'].apply(lambda x: 1 if x.upper() == 'M' else 0)

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0          0  ...       0  White-European      no     no
# 1         1         0          1  ...       1          Latino      no    yes
# 2         1         1          1  ...       1          Latino     yes    yes
# 3         1         0          1  ...       0  White-European      no    yes
# 4         1         0          0  ...       0               ?      no     no
#
#      contry_of_res used_app_before result       age_desc relation Class
# 0  'United States'              no      6  '18 and more'     Self    NO
# 1           Brazil              no      5  '18 and more'     Self    NO
# 2            Spain              no      8  '18 and more'   Parent   YES
# 3  'United States'              no      6  '18 and more'     Self    NO
# 4            Egypt              no      2  '18 and more'        ?    NO
#
# [5 rows x 21 columns]

# %%
# Get unique values in ethnicity column
unique_ethnicities = df['ethnicity'].unique()

unique_ethnicities
# Out:
# array(['White-European', 'Latino', '?', 'Others', 'Black', 'Asian',
#        "'Middle Eastern '", 'Pasifika', "'South Asian'", 'Hispanic',
#        'Turkish', 'others'], dtype=object)

# %%
# Replace 'Middle Eastern ' with 'Middle Eastern' (removing extra space and quote)
df['ethnicity'] = df['ethnicity'].replace("'Middle Eastern '", 'Middle Eastern')
df['ethnicity'] = df['ethnicity'].replace("'South Asian'", 'South Asian')

# Verify the change
print("\nUnique ethnicities after cleaning Middle Eastern values:")
print(df['ethnicity'].unique())
# Out:
# Unique ethnicities after cleaning Middle Eastern values:
# ['White-European' 'Latino' '?' 'Others' 'Black' 'Asian' 'Middle Eastern'
#  'Pasifika' 'South Asian' 'Hispanic' 'Turkish' 'others']

# %%
# Get unique values in ethnicity column
unique_ethnicities = df['ethnicity'].unique()

unique_ethnicities
# Out:
# array(['White-European', 'Latino', '?', 'Others', 'Black', 'Asian',
#        'Middle Eastern', 'Pasifika', 'South Asian', 'Hispanic', 'Turkish',
#        'others'], dtype=object)

# %%
# Drop rows where ethnicity is '?'
df = df[df['ethnicity'] != '?']

# %%
df['ethnicity'].value_counts()
# Out:
# ethnicity
# White-European    233
# Asian             123
# Middle Eastern     92
# Black              43
# South Asian        36
# Others             30
# Latino             20
# Hispanic           13
# Pasifika           11
# Turkish             6
# others              1
# Name: count, dtype: int64

# %%
df=df[df['ethnicity'] != 'others']

# %%
df['ethnicity'] = df['ethnicity'].str.strip().str.lower()

# %%
df['ethnicity'].value_counts()
# Out:
# ethnicity
# white-european    233
# asian             123
# middle eastern     92
# black              43
# south asian        36
# others             30
# latino             20
# hispanic           13
# pasifika           11
# turkish             6
# Name: count, dtype: int64

# %%
# Count occurrences
ethnicity_counts = df['ethnicity'].value_counts()

# Keep ethnicities with at least 50 samples (example threshold)
main_ethnicities = ethnicity_counts[ethnicity_counts >= 40].index

# Group all others as 'other'
df['ethnicity_grouped'] = df['ethnicity'].apply(lambda x: x if x in main_ethnicities else 'other')

# %%
df['ethnicity_grouped'].value_counts()
# Out:
# ethnicity_grouped
# white-european    233
# asian             123
# other             116
# middle eastern     92
# black              43
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 5         1         1         1         1         1         0         1
#
#    A8_Score  A9_Score  A10_Score  ...       ethnicity  jundice austim  \
# 0         1         0          0  ...  white-european       no     no
# 1         1         0          1  ...          latino       no    yes
# 2         1         1          1  ...          latino      yes    yes
# 3         1         0          1  ...  white-european       no    yes
# 5         1         1          1  ...          others      yes     no
#
#      contry_of_res used_app_before result       age_desc  relation Class  \
# 0  'United States'              no      6  '18 and more'      Self    NO
# 1           Brazil              no      5  '18 and more'      Self    NO
# 2            Spain              no      8  '18 and more'    Parent   YES
# 3  'United States'              no      6  '18 and more'      Self    NO
# 5  'United States'              no      9  '18 and more'      Self   YES
#
#   ethnicity_grouped
# 0    white-european
# 1             other
# 2             other
# 3    white-european
# 5             other
#
# [5 rows x 22 columns]

# %%
df.drop(columns=['ethnicity'], inplace=True)

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 5         1         1         1         1         1         0         1
#
#    A8_Score  A9_Score  A10_Score  ...  gender  jundice austim  \
# 0         1         0          0  ...       0       no     no
# 1         1         0          1  ...       1       no    yes
# 2         1         1          1  ...       1      yes    yes
# 3         1         0          1  ...       0       no    yes
# 5         1         1          1  ...       1      yes     no
#
#      contry_of_res used_app_before result       age_desc relation Class  \
# 0  'United States'              no      6  '18 and more'     Self    NO
# 1           Brazil              no      5  '18 and more'     Self    NO
# 2            Spain              no      8  '18 and more'   Parent   YES
# 3  'United States'              no      6  '18 and more'     Self    NO
# 5  'United States'              no      9  '18 and more'     Self   YES
#
#   ethnicity_grouped
# 0    white-european
# 1             other
# 2             other
# 3    white-european
# 5             other
#
# [5 rows x 21 columns]

# %%
# Convert to dummies with 0/1 values, then replace with True/False
df = pd.get_dummies(df, columns=['ethnicity_grouped'], prefix='ethnicity', drop_first=True)
df = df.replace({True: 1, False: 0})
df.head()
# Out:
# C:\Users\chems\AppData\Local\Temp\ipykernel_4588\523825999.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({True: 1, False: 0})
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 5         1         1         1         1         1         0         1
#
#    A8_Score  A9_Score  A10_Score  ...    contry_of_res  used_app_before  \
# 0         1         0          0  ...  'United States'               no
# 1         1         0          1  ...           Brazil               no
# 2         1         1          1  ...            Spain               no
# 3         1         0          1  ...  'United States'               no
# 5         1         1          1  ...  'United States'               no
#
#   result       age_desc relation Class  ethnicity_black  \
# 0      6  '18 and more'     Self    NO                0
# 1      5  '18 and more'     Self    NO                0
# 2      8  '18 and more'   Parent   YES                0
# 3      6  '18 and more'     Self    NO                0
# 5      9  '18 and more'     Self   YES                0
#
#   ethnicity_middle eastern ethnicity_other ethnicity_white-european
# 0                        0               0                        1
# 1                        0               1                        0
# 2                        0               1                        0
# 3                        0               0                        1
# 5                        0               1                        0
#
# [5 rows x 24 columns]

# %%
df.drop(columns=['age_desc'], inplace=True)

# %%
# Display unique values in country_of_res column
print("Unique countries in the dataset:")
print(df['contry_of_res'].unique())

# Show value counts to see distribution
print("\nDistribution of countries:")
print(df['contry_of_res'].value_counts())
# Get value counts
country_counts = df['contry_of_res'].value_counts()

# Drop countries with less than 66 occurrences
df = df[df['contry_of_res'].isin(country_counts[country_counts > 66].index)]

print("\nAfter dropping less frequent countries:")
print(df['contry_of_res'].value_counts())
# Out:
# Unique countries in the dataset:
# ["'United States'" 'other' "'New Zealand'" "'United Arab Emirates'"
#  "'United Kingdom'" 'India']
#
# Distribution of countries:
# contry_of_res
# other                     197
# 'United States'           111
# India                      81
# 'United Kingdom'           76
# 'New Zealand'              75
# 'United Arab Emirates'     67
# Name: count, dtype: int64
#
# After dropping less frequent countries:
# contry_of_res
# other                     197
# 'United States'           111
# India                      81
# 'United Kingdom'           76
# 'New Zealand'              75
# 'United Arab Emirates'     67
# Name: count, dtype: int64

# %%
df['contry_of_res'].value_counts()
# Drop rows where contry_of_res is 'other'
df = df[df['contry_of_res'] != 'other']
df['contry_of_res'].value_counts()
# Out:
# contry_of_res
# 'United States'           111
# India                      81
# 'United Kingdom'           76
# 'New Zealand'              75
# 'United Arab Emirates'     67
# Name: count, dtype: int64

# %%
df['contry_of_res'].value_counts()
# Out:
# contry_of_res
# 'United States'           111
# India                      81
# 'United Kingdom'           76
# 'New Zealand'              75
# 'United Arab Emirates'     67
# Name: count, dtype: int64

# %%
# Replace specific country values with proper formatting
df['contry_of_res'] = df['contry_of_res'].replace({
    "'United States'": "United States",
    "'United Kingdom'": "United Kingdom", 
    "'New Zealand'": "New Zealand",
    "'United Arab Emirates'": "United Arab Emirates"
})

# Verify the changes
print("Updated country values:")
print(df['contry_of_res'].value_counts())
# Out:
# Updated country values:
# contry_of_res
# United States           111
# India                    81
# United Kingdom           76
# New Zealand              75
# United Arab Emirates     67
# Name: count, dtype: int64

# %%
df['contry_of_res'].value_counts()
# Out:
# contry_of_res
# United States           111
# India                    81
# United Kingdom           76
# New Zealand              75
# United Arab Emirates     67
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 3         1         1         0         1         0         0         1
#
#    A8_Score  A9_Score  A10_Score  ...  austim  contry_of_res used_app_before  \
# 0         1         0          0  ...      no  United States              no
# 3         1         0          1  ...     yes  United States              no
#
#   result relation Class  ethnicity_black ethnicity_middle eastern  \
# 0      6     Self    NO                0                        0
# 3      6     Self    NO                0                        0
#
#   ethnicity_other  ethnicity_white-european
# 0               0                         1
# 3               0                         1
#
# [2 rows x 23 columns]

# %%
df['austim'] = df['austim'].replace({'no': 0, 'yes':1})

df['austim'].value_counts()

df.head()
# Out:
# C:\Users\chems\AppData\Local\Temp\ipykernel_4588\212912566.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['austim'] = df['austim'].replace({'no': 0, 'yes':1})
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 3         1         1         0         1         0         0         1
# 5         1         1         1         1         1         0         1
# 6         0         1         0         0         0         0         0
# 7         1         1         1         1         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  austim  contry_of_res used_app_before  \
# 0         1         0          0  ...       0  United States              no
# 3         1         0          1  ...       1  United States              no
# 5         1         1          1  ...       0  United States              no
# 6         1         0          0  ...       0  United States              no
# 7         0         1          0  ...       0    New Zealand              no
#
#    result relation Class  ethnicity_black ethnicity_middle eastern  \
# 0       6     Self    NO                0                        0
# 3       6     Self    NO                0                        0
# 5       9     Self   YES                0                        0
# 6       2     Self    NO                1                        0
# 7       5   Parent    NO                0                        0
#
#   ethnicity_other  ethnicity_white-european
# 0               0                         1
# 3               0                         1
# 5               1                         0
# 6               0                         0
# 7               0                         1
#
# [5 rows x 23 columns]

# %%
df['used_app_before'] = df['used_app_before'].replace({'no': 0, 'yes':1})

df['used_app_before'].value_counts()

df.head()
# Out:
# C:\Users\chems\AppData\Local\Temp\ipykernel_4588\3478061043.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['used_app_before'] = df['used_app_before'].replace({'no': 0, 'yes':1})
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 3         1         1         0         1         0         0         1
# 5         1         1         1         1         1         0         1
# 6         0         1         0         0         0         0         0
# 7         1         1         1         1         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  austim  contry_of_res used_app_before  \
# 0         1         0          0  ...       0  United States               0
# 3         1         0          1  ...       1  United States               0
# 5         1         1          1  ...       0  United States               0
# 6         1         0          0  ...       0  United States               0
# 7         0         1          0  ...       0    New Zealand               0
#
#    result relation  Class  ethnicity_black ethnicity_middle eastern  \
# 0       6     Self     NO                0                        0
# 3       6     Self     NO                0                        0
# 5       9     Self    YES                0                        0
# 6       2     Self     NO                1                        0
# 7       5   Parent     NO                0                        0
#
#   ethnicity_other  ethnicity_white-european
# 0               0                         1
# 3               0                         1
# 5               1                         0
# 6               0                         0
# 7               0                         1
#
# [5 rows x 23 columns]

# %%
df.drop(columns=['result'], inplace=True)

# %%
df['jundice'].value_counts()
# Out:
# jundice
# 0    370
# 1     40
# Name: count, dtype: int64

# %%
df['jundice'] = df['jundice'].replace({'no': 0, 'yes':1})
# Out:
# C:\Users\chems\AppData\Local\Temp\ipykernel_4588\2101673945.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['jundice'] = df['jundice'].replace({'no': 0, 'yes':1})

# %%
df.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'jundice', 'austim', 'contry_of_res', 'used_app_before', 'relation',
#        'Class', 'ethnicity_black', 'ethnicity_middle eastern',
#        'ethnicity_other', 'ethnicity_white-european'],
#       dtype='object')

# %%
df['contry_of_res'].value_counts()
# Out:
# contry_of_res
# United States           111
# India                    81
# United Kingdom           76
# New Zealand              75
# United Arab Emirates     67
# Name: count, dtype: int64

# %%
top_n = 3
top_countries = df['contry_of_res'].value_counts().nlargest(top_n).index

# %%
df['country_grouped'] = df['contry_of_res'].apply(lambda x: x if x in top_countries else 'Other')

# %%
dummies = pd.get_dummies(df['country_grouped'], prefix='country')

# %%
df = pd.concat([df, dummies], axis=1)

# %%
df.sample(10)
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 394         1         0         0         0         1         1         0
# 633         1         1         0         0         1         0         0
# 473         1         0         0         0         0         0         0
# 454         1         1         0         0         0         0         1
# 31          1         0         0         1         1         1         1
# 3           1         1         0         1         0         0         1
# 240         1         0         0         1         1         0         1
# 635         0         1         1         0         0         0         1
# 125         1         1         0         0         1         1         1
# 516         1         1         0         1         0         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  Class  ethnicity_black  \
# 394         1         0          1  ...      0                1
# 633         1         1          1  ...      0                0
# 473         1         0          1  ...      0                0
# 454         0         0          0  ...      0                1
# 31          1         0          1  ...      1                0
# 3           1         0          1  ...      0                0
# 240         1         0          0  ...      0                0
# 635         0         0          1  ...      0                0
# 125         1         0          1  ...      1                0
# 516         0         0          0  ...      0                0
#
#      ethnicity_middle eastern  ethnicity_other ethnicity_white-european  \
# 394                         0                0                        0
# 633                         1                0                        0
# 473                         0                0                        0
# 454                         0                0                        0
# 31                          0                0                        1
# 3                           0                0                        1
# 240                         0                0                        0
# 635                         0                0                        1
# 125                         0                0                        1
# 516                         0                0                        1
#
#      country_grouped country_India  country_Other  country_United Kingdom  \
# 394            Other         False           True                   False
# 633            India          True          False                   False
# 473            India          True          False                   False
# 454            Other         False           True                   False
# 31     United States         False          False                   False
# 3      United States         False          False                   False
# 240            Other         False           True                   False
# 635   United Kingdom         False          False                    True
# 125            Other         False           True                   False
# 516    United States         False          False                   False
#
#      country_United States
# 394                  False
# 633                  False
# 473                  False
# 454                  False
# 31                    True
# 3                     True
# 240                  False
# 635                  False
# 125                  False
# 516                   True
#
# [10 rows x 27 columns]

# %%
df.replace({'NO': 0, 'YES': 1, 'no': 0, 'yes': 1}, inplace=True)

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 3         1         1         0         1         0         0         1
# 5         1         1         1         1         1         0         1
# 6         0         1         0         0         0         0         0
# 7         1         1         1         1         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  Class  ethnicity_black  \
# 0         1         0          0  ...      0                0
# 3         1         0          1  ...      0                0
# 5         1         1          1  ...      1                0
# 6         1         0          0  ...      0                1
# 7         0         1          0  ...      0                0
#
#    ethnicity_middle eastern  ethnicity_other ethnicity_white-european  \
# 0                         0                0                        1
# 3                         0                0                        1
# 5                         0                1                        0
# 6                         0                0                        0
# 7                         0                0                        1
#
#    country_grouped country_India  country_Other  country_United Kingdom  \
# 0    United States         False          False                   False
# 3    United States         False          False                   False
# 5    United States         False          False                   False
# 6    United States         False          False                   False
# 7            Other         False           True                   False
#
#    country_United States
# 0                   True
# 3                   True
# 5                   True
# 6                   True
# 7                  False
#
# [5 rows x 27 columns]

# %%
df = df.replace({True: 1, False: 0})
# Out:
# C:\Users\chems\AppData\Local\Temp\ipykernel_4588\3074727906.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({True: 1, False: 0})

# %%
df
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 3           1         1         0         1         0         0         1
# 5           1         1         1         1         1         0         1
# 6           0         1         0         0         0         0         0
# 7           1         1         1         1         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 690         0         0         0         0         1         0         0
# 691         1         0         0         1         0         0         1
# 692         1         1         1         0         1         1         1
# 693         1         0         0         1         0         0         0
# 694         1         1         1         1         1         0         0
#
#      A8_Score  A9_Score  A10_Score  ...  Class  ethnicity_black  \
# 0           1         0          0  ...      0                0
# 3           1         0          1  ...      0                0
# 5           1         1          1  ...      1                0
# 6           1         0          0  ...      0                1
# 7           0         1          0  ...      0                0
# ..        ...       ...        ...  ...    ...              ...
# 690         0         0          0  ...      0                0
# 691         1         0          0  ...      0                1
# 692         1         0          1  ...      1                0
# 693         1         0          1  ...      0                0
# 694         1         0          1  ...      1                0
#
#      ethnicity_middle eastern  ethnicity_other ethnicity_white-european  \
# 0                           0                0                        1
# 3                           0                0                        1
# 5                           0                1                        0
# 6                           0                0                        0
# 7                           0                0                        1
# ..                        ...              ...                      ...
# 690                         0                0                        0
# 691                         0                0                        0
# 692                         0                0                        1
# 693                         0                0                        1
# 694                         0                0                        1
#
#      country_grouped country_India  country_Other  country_United Kingdom  \
# 0      United States             0              0                       0
# 3      United States             0              0                       0
# 5      United States             0              0                       0
# 6      United States             0              0                       0
# 7              Other             0              1                       0
# ..               ...           ...            ...                     ...
# 690            India             1              0                       0
# 691    United States             0              0                       0
# 692    United States             0              0                       0
# 693   United Kingdom             0              0                       1
# 694    United States             0              0                       0
#
#      country_United States
# 0                        1
# 3                        1
# 5                        1
# 6                        1
# 7                        0
# ..                     ...
# 690                      0
# 691                      1
# 692                      1
# 693                      0
# 694                      1
#
# [410 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'jundice', 'austim', 'contry_of_res', 'used_app_before', 'relation',
#        'Class', 'ethnicity_black', 'ethnicity_middle eastern',
#        'ethnicity_other', 'ethnicity_white-european', 'country_grouped',
#        'country_India', 'country_Other', 'country_United Kingdom',
#        'country_United States'],
#       dtype='object')

# %%
# Group relation into Parent, Self, or Other
df['relation'] = df['relation'].apply(lambda x: x if x in ['Parent', 'Self'] else 'Other')

# Get dummies for the grouped relation
relation_dummies = pd.get_dummies(df['relation'], prefix='relation')

# Add dummies to dataframe
df = pd.concat([df, relation_dummies], axis=1)

# Show the counts of the grouped relation
df['relation'].value_counts()
# Out:
# relation
# Self      358
# Parent     26
# Other      26
# Name: count, dtype: int64

# %%
df = df.replace({True: 1, False: 0})

# %%
df = df.drop(columns=['relation'])

# %%
df = df.drop(columns=['country_grouped'])

# %%
df.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'jundice', 'austim', 'contry_of_res', 'used_app_before', 'Class',
#        'ethnicity_black', 'ethnicity_middle eastern', 'ethnicity_other',
#        'ethnicity_white-european', 'country_India', 'country_Other',
#        'country_United Kingdom', 'country_United States', 'relation_Other',
#        'relation_Parent', 'relation_Self'],
#       dtype='object')

# %%
df.rename(columns={'Class': 'class'}, inplace=True)

# %%
df['class'].value_counts()
# Out:
# class
# 0    306
# 1    104
# Name: count, dtype: int64

# %%
df.applymap(type).eq(str).any().any()
# Out:
# C:\Users\chems\AppData\Local\Temp\ipykernel_4588\846414795.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(type).eq(str).any().any()
# np.True_
